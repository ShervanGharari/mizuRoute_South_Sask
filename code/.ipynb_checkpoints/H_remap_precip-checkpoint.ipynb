# %%
# section 1 load all the necessary modules and packages
import glob
import time
import geopandas as gpd
import netCDF4 as nc4
import numpy as np
import pandas as pd
import xarray as xr
from shapely.geometry import Polygon
# not neccessary for the function but for visualziation
import matplotlib.pyplot as plt
import warnings
import sys
import os
# Out:
# /Users/shg096/opt/anaconda3/envs/myenv38/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# # easymore, creating the remap for lake

# %%
# initializing EASYMORE object
esmr = easymore()

# specifying EASYMORE objects
# name of the case; the temporary, remapping and remapped file names include case name
esmr.case_name                = 'South_Sasktoon_lake'              
# temporary path that the EASYMORE generated GIS files and remapped file will be saved
esmr.temp_dir                 = '../temporary/'
# name of target shapefile that the source netcdf files should be remapped to
esmr.target_shp               = '../shp/cat_lake_area_corrected_71021602.shp' # cats and lakes
esmr.target_shp_ID            = 'cat_id'
esmr.var_ID                   = 'ID'
# name of netCDF file(s); multiple files can be specified with *
# from the files located in project space
# 
esmr.source_nc                = '/Users/shg096/Downloads/clm50sp_release-clm5.0.20_0.5deg_GSWP3V1_LakeEvap_2000.clm2.*-01-01-00000.nc'
# name of variables from source netCDF file(s) to be remapped
esmr.var_names                = ['QRUNOFF','PRECIP','EVAP']
# name of variable longitude in source netCDF files
esmr.var_lon                  = 'lon'
# name of variable latitude in source netCDF files
esmr.var_lat                  = 'lat'
# name of variable time in source netCDF file; should be always time
esmr.var_time                 = 'time'
# location where the remapped netCDF file will be saved
esmr.output_dir               = '../output/'
# format of the variables to be saved in remapped files,
# if one format provided it will be expanded to other variables
esmr.format_list              = ['f4']
# fill values of the variables to be saved in remapped files,
# if one value provided it will be expanded to other variables
esmr.fill_value_list          = ['-99999.00']
# if required that the remapped values to be saved as csv as well
#esmr.save_csv                 = True
esmr.complevel                 =  9
# if uncommented EASYMORE will use this and skip GIS tasks
esmr.remap_csv                = '../temporary/South_Sasktoon_lake_remapping.csv'

# execute EASYMORE
esmr.nc_remapper()
# Out:
# EASYMORE version 0.0.2 is initiated.
# no author name is provide and the author name is changed to (author name)!
# EASYMORE is given multiple varibales to be remapped but only on format and fill valueEASYMORE repeat the format and fill value for all the variables in output files
# EASYMORE will remap variable  QRUNOFF  from source file to variable  QRUNOFF  in remapped NeCDF file
# EASYMORE will remap variable  PRECIP  from source file to variable  PRECIP  in remapped NeCDF file
# EASYMORE will remap variable  EVAP  from source file to variable  EVAP  in remapped NeCDF file
# EASYMORE detects that target shapefile is in WGS84 (epsg:4326)
# EASYMORE detects that the field for ID is provided in sink/target shapefile
# EASYMORE detects that either of the fields for latitude or longitude is not provided in sink/target shapefile
# calculating centroid of shapes in WGS84 projection;
# for better appximation use the easymore equal area centroid function to preprocess target shapefile
# ...

# %%
ds = xr.open_dataset('../output/South_Sasktoon_lake_remapped_1989-01-01-00-00-00.nc')
print(ds)

plt.plot(ds['QRUNOFF'][:,500])
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 365, ID: 3062)
# Coordinates:
#   * time       (time) object 1989-01-01 00:00:00 ... 1989-12-31 00:00:00
#   * ID         (ID) float64 7.102e+07 7.104e+07 ... 9.699e+05 9.777e+05
# Data variables:
#     latitude   (ID) float64 ...
#     longitude  (ID) float64 ...
#     QRUNOFF    (time, ID) float32 ...
#     PRECIP     (time, ID) float32 ...
#     EVAP       (time, ID) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     Author:       The data were written by author name
#     License:
#     History:      Created Fri Jan  7 10:41:53 2022
#     Source:       Case: South_Sasktoon_lake; remapped by script from library ...

# %% [markdown]
# # easymore, creating the remap for no lake

# %%
# initializing EASYMORE object
esmr = easymore()

# specifying EASYMORE objects
# name of the case; the temporary, remapping and remapped file names include case name
esmr.case_name                = 'South_Sasktoon_no_lake'              
# temporary path that the EASYMORE generated GIS files and remapped file will be saved
esmr.temp_dir                 = '../temporary/'
# name of target shapefile that the source netcdf files should be remapped to
esmr.target_shp               = '../shp/cat_71021602.shp' # cats and lakes
esmr.target_shp_ID            = 'cat_id'
esmr.var_ID                   = 'ID'
# name of netCDF file(s); multiple files can be specified with *
# from the files located in project space
# 
esmr.source_nc                = '/Users/shg096/Downloads/clm50sp_release-clm5.0.20_0.5deg_GSWP3V1_LakeEvap_2000.clm2.*-01-01-00000.nc'
# name of variables from source netCDF file(s) to be remapped
esmr.var_names                = ['QRUNOFF','PRECIP','EVAP']
# name of variable longitude in source netCDF files
esmr.var_lon                  = 'lon'
# name of variable latitude in source netCDF files
esmr.var_lat                  = 'lat'
# name of variable time in source netCDF file; should be always time
esmr.var_time                 = 'time'
# location where the remapped netCDF file will be saved
esmr.output_dir               = '../output/'
# format of the variables to be saved in remapped files,
# if one format provided it will be expanded to other variables
esmr.format_list              = ['f4']
# fill values of the variables to be saved in remapped files,
# if one value provided it will be expanded to other variables
esmr.fill_value_list          = ['-99999.00']
# if required that the remapped values to be saved as csv as well
#esmr.save_csv                 = True
esmr.complevel                 =  9
# if uncommented EASYMORE will use this and skip GIS tasks
esmr.remap_csv                = '../temporary/South_Sasktoon_no_lake_remapping.csv'

# execute EASYMORE
esmr.nc_remapper()
# Out:
# EASYMORE version 0.0.2 is initiated.
# no author name is provide and the author name is changed to (author name)!
# EASYMORE is given multiple varibales to be remapped but only on format and fill valueEASYMORE repeat the format and fill value for all the variables in output files
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  QRUNOFF  from source file to variable  QRUNOFF  in remapped NeCDF file
# EASYMORE will remap variable  PRECIP  from source file to variable  PRECIP  in remapped NeCDF file
# EASYMORE will remap variable  EVAP  from source file to variable  EVAP  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'lat', 'lon']
# EASYMORE detects that the longitude varibales has dimensions of:
# ...

# %%
ds = xr.open_dataset('../output/South_Sasktoon_no_lake_remapped_1989-01-01-00-00-00.nc')
print(ds)
print(ds['ID'])

plt.plot(ds['QRUNOFF'][:,8])
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 365, ID: 2993)
# Coordinates:
#   * time       (time) object 1989-01-01 00:00:00 ... 1989-12-31 00:00:00
#   * ID         (ID) float64 7.102e+07 7.104e+07 ... 7.104e+07 7.103e+07
# Data variables:
#     latitude   (ID) float64 ...
#     longitude  (ID) float64 ...
#     QRUNOFF    (time, ID) float32 ...
#     PRECIP     (time, ID) float32 ...
#     EVAP       (time, ID) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     Author:       The data were written by author name
#     License:
#     History:      Created Fri Jan  7 10:54:04 2022
#     Source:       Case: South_Sasktoon_no_lake; remapped by script from libra...
# <xarray.DataArray 'ID' (ID: 2993)>
# array([71022453., 71039295., 71039293., ..., 71039369., 71039368., 71033584.])
# Coordinates:
#   * ID       (ID) float64 7.102e+07 7.104e+07 7.104e+07 ... 7.104e+07 7.103e+07
# Attributes:
#     long_name:  shape ID
#     units:      1
