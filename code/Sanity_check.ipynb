# %%
# section 1 load all the necessary modules and packages
import glob
import time
import geopandas as gpd
import netCDF4 as nc4
import numpy as np
import pandas as pd
import xarray as xr
from shapely.geometry import Polygon
# not neccessary for the function but for visualziation
import matplotlib.pyplot as plt
import warnings
import sys
import os
import platform
import shutil
import networkx as nx

# %%
remapping = xr.open_dataset('../data/rempping_file/South_Sasktoon_HDMA_no_lake_remapping.nc')
Ntopo = xr.open_dataset('../data/network_topology/Network_topology_HDMA_no_lake.nc')

# %%
remapping
# Out:
# <xarray.Dataset>
# Dimensions:    (intersect: 1332, polyid: 283)
# Coordinates:
#   * polyid     (polyid) float64 3e+06 3e+06 3e+06 ... 3.044e+06 3.044e+06
# Dimensions without coordinates: intersect
# Data variables:
#     frequency  (polyid) float64 ...
#     IDmask     (intersect) float64 ...
#     weight     (intersect) float64 ...
#     i_index    (intersect) float64 ...
#     j_index    (intersect) float64 ...
# Attributes:
#     Conventions:  CF-1.6
#     Author:       The data were written by easymore_codes
#     License:      MIT
#     History:      Created
#     Source:       Case: ; remapped by script from library of Shervan Gharari ...

# %%
Ntopo
# Out:
# <xarray.Dataset>
# Dimensions:     (n: 283)
# Coordinates:
#     ID          (n) float64 ...
# Dimensions without coordinates: n
# Data variables:
#     Unnamed: 0  (n) int64 ...
#     ID_next     (n) float64 ...
#     length      (n) float64 ...
#     area        (n) float64 ...
#     slope       (n) float64 ...
# Attributes:
#     Conventions:  CF-1.6
#     License:      The data were written by Shervan Gharari. They are under GPL.
#     history:      Created Wed Aug 30 08:43:09 2023
#     source:       Written by test script of utilities (https://github.com/She...
